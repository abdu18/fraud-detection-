# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
id_raw_df   =pd.read_csv("train_identity.csv")
id_trans_df =pd.read_csv("train_transaction.csv")

# %%
id_raw_df.head(10)
# Out:
#    TransactionID  id_01     id_02  id_03  id_04  id_05  id_06  id_07  id_08  \
# 0        2987004    0.0   70787.0    NaN    NaN    NaN    NaN    NaN    NaN
# 1        2987008   -5.0   98945.0    NaN    NaN    0.0   -5.0    NaN    NaN
# 2        2987010   -5.0  191631.0    0.0    0.0    0.0    0.0    NaN    NaN
# 3        2987011   -5.0  221832.0    NaN    NaN    0.0   -6.0    NaN    NaN
# 4        2987016    0.0    7460.0    0.0    0.0    1.0    0.0    NaN    NaN
# 5        2987017   -5.0   61141.0    3.0    0.0    3.0    0.0    NaN    NaN
# 6        2987022  -15.0       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7        2987038    0.0   31964.0    0.0    0.0    0.0  -10.0    NaN    NaN
# 8        2987040  -10.0  116098.0    0.0    0.0    0.0    0.0    NaN    NaN
# 9        2987048   -5.0  257037.0    NaN    NaN    0.0    0.0    NaN    NaN
#
#    id_09  ...                id_31  id_32      id_33           id_34  id_35  \
# ...

# %%
id_trans_df.head(10)
# Out:
#    TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  card1  \
# 0        2987000        0          86400            68.5         W  13926
# 1        2987001        0          86401            29.0         W   2755
# 2        2987002        0          86469            59.0         W   4663
# 3        2987003        0          86499            50.0         W  18132
# 4        2987004        0          86506            50.0         H   4497
# 5        2987005        0          86510            49.0         W   5937
# 6        2987006        0          86522           159.0         W  12308
# 7        2987007        0          86529           422.5         W  12695
# 8        2987008        0          86535            15.0         H   2803
# 9        2987009        0          86536           117.0         W  17399
#
#    card2  card3       card4  card5  ... V330  V331  V332  V333  V334 V335  \
# 0    NaN  150.0    discover  142.0  ...  NaN   NaN   NaN   NaN   NaN  NaN
# ...

# %%
id_raw_df.shape
# Out:
# (144233, 41)

# %%
id_trans_df.shape
# Out:
# (590540, 394)

# %%
id_raw_df.describe()
# Out:
#        TransactionID          id_01          id_02         id_03  \
# count   1.442330e+05  144233.000000  140872.000000  66324.000000
# mean    3.236329e+06     -10.170502  174716.584708      0.060189
# std     1.788496e+05      14.347949  159651.816856      0.598231
# min     2.987004e+06    -100.000000       1.000000    -13.000000
# 25%     3.077142e+06     -10.000000   67992.000000      0.000000
# 50%     3.198818e+06      -5.000000  125800.500000      0.000000
# 75%     3.392923e+06      -5.000000  228749.000000      0.000000
# max     3.577534e+06       0.000000  999595.000000     10.000000
#
#               id_04          id_05          id_06        id_07        id_08  \
# count  66324.000000  136865.000000  136865.000000  5155.000000  5155.000000
# mean      -0.058938       1.615585      -6.698710    13.285354   -38.600388
# std        0.701015       5.249856      16.491104    11.384207    26.084899
# ...

# %%
id_trans_df.describe()
# Out:
#        TransactionID        isFraud  TransactionDT  TransactionAmt  \
# count   5.905400e+05  590540.000000   5.905400e+05   590540.000000
# mean    3.282270e+06       0.034990   7.372311e+06      135.027176
# std     1.704744e+05       0.183755   4.617224e+06      239.162522
# min     2.987000e+06       0.000000   8.640000e+04        0.251000
# 25%     3.134635e+06       0.000000   3.027058e+06       43.321000
# 50%     3.282270e+06       0.000000   7.306528e+06       68.769000
# 75%     3.429904e+06       0.000000   1.124662e+07      125.000000
# max     3.577539e+06       1.000000   1.581113e+07    31937.391000
#
#                card1          card2          card3          card5  \
# count  590540.000000  581607.000000  588975.000000  586281.000000
# mean     9898.734658     362.555488     153.194925     199.278897
# std      4901.170153     157.793246      11.336444      41.244453
# min      1000.000000     100.000000     100.000000     100.000000
# ...

# %% [markdown]
# Merging train_identity & train_transaction csv

# %%
train_full_df = pd.merge(id_trans_df, id_raw_df, on='TransactionID', how='left')

# %%
train_full_df.shape
# Out:
# (590540, 434)

# %%
len(train_full_df[train_full_df["isFraud"]==1])/len(train_full_df)*100
# Out:
# 3.4990009144173126

# %%
train_full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 590540 entries, 0 to 590539
# Columns: 434 entries, TransactionID to DeviceInfo
# dtypes: float64(399), int64(4), object(31)
# memory usage: 1.9+ GB

# %% [markdown]
# VISUALIZE DATASET

# %%
sns.distplot(id_raw_df['id_01'])

# %%
sns.countplot(id_trans_df['isFraud'])

# %%
sns.countplot(id_trans_df['card4'])

# %%
plt.figure(figsize=(30,10)) 
sns.heatmap(id_raw_df.corr(), annot=True)

# %% [markdown]
#  NAs: Drop data / imputte/recode NAs

# %%
columns_def=pd.DataFrame({"na_count":train_full_df.isnull().sum().sort_values(ascending=False)})

# %%
#Create column of percent columns, #higher is worst
columns_def["per"]=columns_def["na_count"]/len(train_full_df)

# %%
#cycle throungh various limit for percent Na per column
range=[0.05, 0.10 ,0.15, 0.25, 0.40, 0.60, 0.75]

# %%
for i in range: 
    print (columns_def[columns_def["per"]<i].shape[0]/train_full_df.shape[1])
# Out:
# 0.25806451612903225
# 0.25806451612903225
# 0.3686635944700461
# 0.41935483870967744
# 0.46543778801843316
# 0.5207373271889401
# 0.5207373271889401

# %%
limit=0.10 #only columns w/ less 10% will remain

# %%
#Select final columns
columns_final=columns_def[columns_def["per"]<limit].index 

train_full_df=train_full_df[train_full_df.columns.intersection(columns_final)]

# %% [markdown]
# Categorical Variables

# %%
train_full_df[train_full_df.select_dtypes(include=['object']).columns]
# Out:
#        ProductCD       card4   card6
# 0              W    discover  credit
# 1              W  mastercard  credit
# 2              W        visa   debit
# 3              W  mastercard   debit
# 4              H  mastercard  credit
# 5              W        visa   debit
# 6              W        visa   debit
# 7              W        visa   debit
# 8              H        visa   debit
# 9              W  mastercard   debit
# 10             C  mastercard  credit
# 11             C  mastercard   debit
# 12             W        visa   debit
# 13             W        visa   debit
# 14             W        visa   debit
# 15             W        visa   debit
# 16             H        visa   debit
# 17             H  mastercard  credit
# 18             W        visa   debit
# 19             W        visa   debit
# 20             W  mastercard   debit
# 21             W  mastercard   debit
# 22             H        visa  credit
# 23             W  mastercard   debit
# ...

# %%
cardTypes = ['discover','mastercard','visa','american express','missing']
for i,i_card in enumerate(cardTypes):
    cardData = eval('id_trans_df.loc[id_trans_df["card4"]=="'+i_card+'"]')
    plt.figure(i)
    sns.countplot(cardData['isFraud']).set_title(i_card)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-3dd88f34d660> in <module>
#       3     cardData = eval('id_trans_df.loc[id_trans_df["card4"]=="'+i_card+'"]')
#       4     plt.figure(i)
# ----> 5     sns.countplot(cardData['isFraud']).set_title(i_card)
#
# //anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3551                           estimator, ci, n_boot, units,
#    3552                           orient, color, palette, saturation,
# -> 3553                           errcolor, errwidth, capsize, dodge)
#    3554
#    3555     plotter.value_label = "count"
#
# ...

# %%
card6_dummy_df=pd.get_dummies(train_full_df["card6"])

# %%
train_full_df.shape
# Out:
# (590540, 112)

# %%
train_full_df=pd.concat([train_full_df,card6_dummy_df],axis=1)

# %%
train_full_df=train_full_df._get_numeric_data()
train_full_df=train_full_df.dropna()

len(train_full_df[train_full_df["isFraud"]==1])/len(train_full_df)*100
# Out:
# 3.46278261170406

# %%
x_full_df=train_full_df.drop(["isFraud"],axis=1)
y_full_df=train_full_df["isFraud"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x_full_df,y_full_df,test_size=0.50)

# %% [markdown]
# Modeling

# %%
from sklearn.linear_model import LogisticRegression  
from sklearn.preprocessing import StandardScaler  

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score

# %%
lr = LogisticRegression(solver='lbfgs')  
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
lr.score(X_test, y_test)
# Out:
# 0.9655347783217146

# %%
y_pred=lr.predict(X_test)

# %%
pd.crosstab(y_test, y_pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted       0   1     All
# True
# 0          279066  34  279100
# 1            9928  17    9945
# All        288994  51  289045

# %%
recall_score(y_test, y_pred)
# Out:
# 0.0017094017094017094

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9655347783217146

# %%
recall_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-165de324052f> in <module>
# ----> 1 recall_score(y_test, y_pred)
#
# NameError: name 'recall_score' is not defined
